# %% [markdown]
# # Российский рынок труда: 2010–2023
#
# Этот ноутбук — тонкий слой представления поверх пакета `labor_market_analysis`. Подготовка данных, расчёты и построение графиков выполняются командами, описанными в README.

# %%
from pathlib import Path

import pandas as pd

REPORTS = Path("../reports")

# %% [markdown]
# ## Динамика безработицы
#
# После полного запуска здесь можно исследовать подготовленные агрегаты без повторной загрузки 12+ млн наблюдений.

# %%
monthly = pd.read_csv(REPORTS / "tables/monthly_unemployment.csv")
monthly.head()

# %% [markdown]
# ## Основные результаты полного запуска
#
# На 12 264 280 наблюдениях месячная безработица снизилась с 9,02% в январе 2010 года до 2,99% в декабре 2023 года. В 2023 году наиболее высокий показатель наблюдался среди групп 15–19 лет (19,64%) и 20–24 года (10,38%). Доля неформальной занятости в сельской местности составляла 26,92% против 15,71% в городах.

# %% [markdown]
# ## Ограничения
#
# Доверительные интервалы используют эффективный размер взвешенной выборки и являются приближёнными: открытая версия набора не содержит всех переменных стратификации и кластеризации обследования.
